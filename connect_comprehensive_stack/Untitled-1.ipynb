# %%
with open('/Users/alokkulkarni/Documents/Development/awsTfElements/resources/firehose/variables.tf', 'r') as f:
    print(f.read())
with open('/Users/alokkulkarni/Documents/Development/awsTfElements/resources/firehose/main.tf', 'r') as f:
    print(f.read())
